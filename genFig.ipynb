# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({
  "text.usetex": True,
  "font.family": "Helvetica"
})
import warnings
warnings.filterwarnings("ignore")

# %%
df_200 = pd.read_csv('./Re_tau_200/momentumNT_200.csv')
df_300 = pd.read_csv('./Re_tau_300/momentumNT_300.csv')
df_100 = pd.read_csv('./Re_tau_100/momentumNT_100.csv')
#df_100 = pd.read_csv('./momentumNT.csv')
df_400 = pd.read_csv('./Re_tau_400/momentumNT_400.csv')

# %%
(n1, m1) = df_100.shape
(n2, m2) = df_200.shape
(n3, m3) = df_300.shape
(n4, m4) = df_400.shape

# %%
df_100 = df_100.iloc[:-int(n1/2)]
df_200 = df_200.iloc[:-int(n2/2)]
df_300 = df_300.iloc[:-int(n3/2)]
df_400 = df_400.iloc[:-int(n4/2)]

# %%
fig.set_figheight(10)
fig.set_figwidth(12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_41881/3707968843.py in <module>
# ----> 1 fig.set_figheight(10)
#       2 fig.set_figwidth(12)
#
# NameError: name 'fig' is not defined

# %%
y_200 = df_200[' "y"'].values
U_200 = df_200.U.values
y_300 = df_300[' "y"'].values
U_300 = df_300.U.values
y_100 = df_100[' "y"'].values
U_100 = df_100.U.values
y_400 = df_400[' "y"'].values
U_400 = df_400.U.values
yl = y_400[0:160]
Ul = yl
yt = y_400[160:-1]
Ut = (1/0.4)*np.log(yt)+5.8
plt.figure(1)
plt.semilogx(yl,Ul,'c-.',yt,Ut,'m--',y_100,U_100,'r:',y_200,U_200,'g-.',y_300,U_300,'b--',y_400,U_400,'k')
plt.xlabel('$y^{+}$')
plt.ylabel('$U^{+}$')
plt.xlim([5e-01,5e+02])
plt.legend(['$U^{+}=y^{+}$','$U^{+}=\kappa^{-1}\ln{y^{+}}+C$',r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$']) 
plt.show()

# %%
k_200 = df_200.k.values
k_300 = df_300.k.values
k_100 = df_100.k.values
k_400 = df_400.k.values
plt.figure(2)
plt.semilogx(y_100,k_100,'r:',y_200,k_200,'g-.',y_300,k_300,'b--',y_400,k_400,'k')
plt.xlabel('$y^{+}$')
plt.ylabel('$k^{+}$')
plt.xlim([5e-01,5e+02])
#plt.ylim([0, 20])
plt.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$']) 
plt.show()

# %%
eps_200 = df_200.epsilon.values
eps_300 = df_300.epsilon.values
eps_100 = df_100.epsilon.values
eps_400 = df_400.epsilon.values
plt.figure(3)
plt.semilogx(y_100,eps_100,'r:',y_200,eps_200,'g-.',y_300,eps_300,'b--',y_400,eps_400,'k')
plt.xlabel('$y^{+}$')
plt.ylabel('$\epsilon^{+}$')
plt.xlim([5e-01,5e+02])
#plt.ylim([0, 20])
plt.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$']) 
plt.show()

# %%
nut_200 = df_200.nut.values
nut_300 = df_300.nut.values
nut_100 = df_100.nut.values
nut_400 = df_400.nut.values
plt.figure(4)
plt.semilogx(y_100,nut_100,'r:',y_200,nut_200,'g-.',y_300,nut_300,'b--',y_400,nut_400,'k')
plt.xlabel('$y^{+}$')
plt.ylabel(r'$\nu^{+}_T$')
plt.xlim([5e-01,5e+02])
#plt.ylim([0, 20])
plt.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$']) 
plt.show()

# %%
tau_R_200 = df_200.tau_R.values
tau_R_300 = df_300.tau_R.values
tau_R_100 = df_100.tau_R.values
tau_R_400 = df_400.tau_R.values
plt.figure(5)
plt.semilogx(y_100,tau_R_100,'r:',y_200,tau_R_200,'g-.',y_300,tau_R_300,'b--',y_400,tau_R_400,'k')
plt.xlabel('$y^{+}$')
plt.ylabel(r'$\tau^{+}_R$')
plt.xlim([5e-01,5e+02])
#plt.ylim([0, 20])
plt.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$']) 
plt.show()

# %%
tau_mu_200 = df_200.tau_mu.values
tau_mu_300 = df_300.tau_mu.values
tau_mu_100 = df_100.tau_mu.values
tau_mu_400 = df_400.tau_mu.values
plt.figure(3)
plt.semilogx(y_100,tau_mu_100,'r:',y_200,tau_mu_200,'g-.',y_300,tau_mu_300,'b--',y_400,tau_mu_400,'k')
plt.xlabel('$y^{+}$')
plt.ylabel(r'$\tau^{+}_{\mu}$')
plt.xlim([5e-01,5e+02])
#plt.ylim([0, 20])
plt.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$']) 
plt.show()

# %%
fontSize=18
fontSizeLeg=14

# %%
#fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1)

fig.set_figheight(24)
fig.set_figwidth(6)
plt.rcParams['font.size'] = 16

ax1.semilogx(yl,Ul,'c-.',yt,Ut,'m--',y_100,U_100,'r:',y_200,U_200,'g-.',y_300,U_300,'b--',y_400,U_400,'k')
#ax1.set_xlabel('$y^{+}$')
ax1.text(3e-01,23,'a)',fontsize=fontSize)
ax1.set_ylabel('$U^{+}$',fontsize=fontSize)
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([5e-01,5e+02])
ax1.legend(['$U^{+}=y^{+}$','$U^{+}=\kappa^{-1}\ln{y^{+}}+C$',r'$Re_{\tau}=100$',
            r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax2.semilogx(y_100,k_100,'r:',y_200,k_200,'g-.',y_300,k_300,'b--',y_400,k_400,'k')
#ax2.set_xlabel('$y^{+}$')
ax2.text(3e-01,4.2,'b)',fontsize=fontSize)
ax2.set_ylabel('$k^{+}$',fontsize=fontSize)
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([5e-01,5e+02])
#ax2.set_aspect("equal")
ax2.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
ax3.semilogx(y_100,eps_100,'r:',y_200,eps_200,'g-.',y_300,eps_300,'b--',y_400,eps_400,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_ylabel('$\epsilon^{+}$',fontsize=fontSize)
ax3.text(3e-01,0.2,'c)',fontsize=fontSize)
ax3.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax4.semilogx(y_100,nut_100,'r:',y_200,nut_200,'g-.',y_300,nut_300,'b--',y_400,nut_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_ylabel(r'$\nu^{+}_T$',fontsize=fontSize)
ax4.text(3e-01,45,'d)',fontsize=fontSize)
ax4.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax4.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
plt.savefig("Fig_momentum_col_eps.eps", format="eps", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
plt.savefig("Fig_momentum_col_eps.png", format="png", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

fig.set_figheight(12)
fig.set_figwidth(12)
plt.rcParams['font.size'] = 16

ax1.semilogx(yl,Ul,'c-.',yt,Ut,'m--',y_100,U_100,'r:',y_200,U_200,'g-.',y_300,U_300,'b--',y_400,U_400,'k')
#ax1.set_xlabel('$y^{+}$')
ax1.text(3e-01,23,'a)',fontsize=fontSize)
ax1.set_ylabel('$U^{+}$',fontsize=fontSize)
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([5e-01,5e+02])
ax1.legend(['$U^{+}=y^{+}$','$U^{+}=\kappa^{-1}\ln{y^{+}}+C$',r'$Re_{\tau}=100$',
            r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax2.semilogx(y_100,k_100,'r:',y_200,k_200,'g-.',y_300,k_300,'b--',y_400,k_400,'k')
#ax2.set_xlabel('$y^{+}$')
ax2.text(3e-01,4.2,'b)',fontsize=fontSize)
ax2.set_ylabel('$k^{+}$',fontsize=fontSize)
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([5e-01,5e+02])
#ax2.set_aspect("equal")
ax2.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
ax3.semilogx(y_100,eps_100,'r:',y_200,eps_200,'g-.',y_300,eps_300,'b--',y_400,eps_400,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_ylabel('$\epsilon^{+}$',fontsize=fontSize)
ax3.text(3e-01,0.2,'c)',fontsize=fontSize)
ax3.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax4.semilogx(y_100,nut_100,'r:',y_200,nut_200,'g-.',y_300,nut_300,'b--',y_400,nut_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_ylabel(r'$\nu^{+}_T$',fontsize=fontSize)
ax4.text(3e-01,45,'d)',fontsize=fontSize)
ax4.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax4.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
plt.savefig("Fig_momentum_sqr_eps.eps", format="eps", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
plt.savefig("Fig_momentum_sqr_eps.png", format="png", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1)
fontSizeLeg=16

fig.set_figheight(24)
fig.set_figwidth(6)
plt.rcParams['font.size'] = 16

ax1.semilogx(yl,Ul,'c-.',yt,Ut,'m--',y_100,U_100,'r:',y_200,U_200,'g-.',y_300,U_300,'b--',y_400,U_400,'k')
#ax1.set_xlabel('$y^{+}$')
ax1.text(3e-01,27,'a)',fontsize=fontSize)
ax1.set_ylabel('$U^{+}$',fontsize=fontSize)
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([5e-01,5e+02])
ax1.set_ylim([0,25])
ax1.legend(['$U^{+}=y^{+}$','$U^{+}=\kappa^{-1}\ln{y^{+}}+C$',r'$Re_{\tau}=100$',
            r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=14) 
ax2.semilogx(y_100,k_100,'r:',y_200,k_200,'g-.',y_300,k_300,'b--',y_400,k_400,'k')
#ax2.set_xlabel('$y^{+}$')
ax2.text(3e-01,4.2,'b)',fontsize=fontSize)
ax2.set_ylabel('$k^{+}$',fontsize=fontSize)
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([5e-01,5e+02])
#ax2.set_aspect("equal")
ax2.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
ax3.semilogx(y_100,tau_R_100,'r:',y_200,tau_R_200,'g-.',y_300,tau_R_300,'b--',y_400,tau_R_400,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_ylabel(r'$\tau^{+}_R$',fontsize=fontSize)
ax3.text(3e-01,0.9,'c)',fontsize=fontSize)
ax3.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax4.semilogx(y_100,nut_100,'r:',y_200,nut_200,'g-.',y_300,nut_300,'b--',y_400,nut_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_ylabel(r'$\nu^{+}_T$',fontsize=fontSize)
ax4.text(3e-01,45,'d)',fontsize=fontSize)
ax4.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax4.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
plt.savefig("Fig_momentum_col_tau.eps", format="eps", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
plt.savefig("Fig_momentum_col_tau.png", format="png", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fontSizeLeg=16

fig.set_figheight(12)
fig.set_figwidth(12)
plt.rcParams['font.size'] = 16

ax1.semilogx(yl,Ul,'c-.',yt,Ut,'m--',y_100,U_100,'r:',y_200,U_200,'g-.',y_300,U_300,'b--',y_400,U_400,'k')
#ax1.set_xlabel('$y^{+}$')
ax1.text(3e-01,27,'a)',fontsize=fontSize)
ax1.set_ylabel('$U^{+}$',fontsize=fontSize)
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([5e-01,5e+02])
ax1.set_ylim([0,25])
ax1.legend(['$U^{+}=y^{+}$','$U^{+}=\kappa^{-1}\ln{y^{+}}+C$',r'$Re_{\tau}=100$',
            r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=14) 
ax2.semilogx(y_100,k_100,'r:',y_200,k_200,'g-.',y_300,k_300,'b--',y_400,k_400,'k')
#ax2.set_xlabel('$y^{+}$')
ax2.text(3e-01,4.2,'b)',fontsize=fontSize)
ax2.set_ylabel('$k^{+}$',fontsize=fontSize)
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([5e-01,5e+02])
#ax2.set_aspect("equal")
ax2.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
ax3.semilogx(y_100,tau_R_100,'r:',y_200,tau_R_200,'g-.',y_300,tau_R_300,'b--',y_400,tau_R_400,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_ylabel(r'$\tau^{+}_R$',fontsize=fontSize)
ax3.text(3e-01,0.9,'c)',fontsize=fontSize)
ax3.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax4.semilogx(y_100,nut_100,'r:',y_200,nut_200,'g-.',y_300,nut_300,'b--',y_400,nut_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_ylabel(r'$\nu^{+}_T$',fontsize=fontSize)
ax4.text(3e-01,45,'d)',fontsize=fontSize)
ax4.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax4.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
plt.savefig("Fig_momentum_sqr_tau.eps", format="eps", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
plt.savefig("Fig_momentum_sqr_tau.png", format="png", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
Pk_100 = df_100.Pk.values
Tk_100 = df_100.Tk.values
Dk_100 = df_100.Dk.values
Pk_200 = df_200.Pk.values
Tk_200 = df_200.Tk.values
Dk_200 = df_200.Dk.values
Pk_300 = df_300.Pk.values
Tk_300 = df_300.Tk.values
Dk_300 = df_300.Dk.values
Pk_400 = df_400.Pk.values
Tk_400 = df_400.Tk.values
Dk_400 = df_400.Dk.values
#fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1)
fontSizeLeg=16

fig.set_figheight(24)
fig.set_figwidth(6)
plt.rcParams['font.size'] = 16

ax1.semilogx(y_100,Pk_100,'r:',y_200,Pk_200,'g-.',y_300,Pk_300,'b--',y_400,Pk_400,'k')
ax1.text(3e-01,0.26,'a)',fontsize=fontSize)
ax1.set_ylabel('$P^{+}_{k}$',fontsize=fontSize)
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([5e-01,5e+02])
ax1.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax2.semilogx(y_100,Tk_100,'r:',y_200,Tk_200,'g-.',y_300,Tk_300,'b--',y_400,Tk_400,'k')
ax2.text(3e-01,0.0475,'b)',fontsize=fontSize)
ax2.set_ylabel('$T^{+}_{k}$',fontsize=fontSize)
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([5e-01,5e+02])
#ax2.set_aspect("equal")
ax2.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
ax3.semilogx(y_100,Dk_100,'r:',y_200,Dk_200,'g-.',y_300,Dk_300,'b--',y_400,Dk_400,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_ylabel('$D^{+}_{k}$',fontsize=fontSize)
ax3.text(3e-01,0.095,'c)',fontsize=fontSize)
ax3.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax4.semilogx(y_100,eps_100,'r:',y_200,eps_200,'g-.',y_300,eps_300,'b--',y_400,eps_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_ylabel(r'$\epsilon^{+}$',fontsize=fontSize)
ax4.text(3e-01,0.195,'d)',fontsize=fontSize)
ax4.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax4.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
plt.savefig("Fig_Budget_k_col.eps", format="eps", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
#plt.savefig("Fig_momentum_col_tau.png", format="png", dpi=1200, transparent=False, bbox_inches = 'tight',pad_inches = 0)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
Pk_100 = df_100.Pk.values
Tk_100 = df_100.Tk.values
Dk_100 = df_100.Dk.values
Pk_200 = df_200.Pk.values
Tk_200 = df_200.Tk.values
Dk_200 = df_200.Dk.values
Pk_300 = df_300.Pk.values
Tk_300 = df_300.Tk.values
Dk_300 = df_300.Dk.values
Pk_400 = df_400.Pk.values
Tk_400 = df_400.Tk.values
Dk_400 = df_400.Dk.values

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fontSizeLeg=16

fig.set_figheight(12)
fig.set_figwidth(12)
plt.rcParams['font.size'] = 16

ax1.semilogx(y_100,Pk_100,'r:',y_200,Pk_200,'g-.',y_300,Pk_300,'b--',y_400,Pk_400,'k')
ax1.text(3e-01,0.26,'a)',fontsize=fontSize)
ax1.set_ylabel('$P^{+}_{k}$',fontsize=fontSize)
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([5e-01,5e+02])
ax1.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax2.semilogx(y_100,Tk_100,'r:',y_200,Tk_200,'g-.',y_300,Tk_300,'b--',y_400,Tk_400,'k')
ax2.text(3e-01,0.0475,'b)',fontsize=fontSize)
ax2.set_ylabel('$T^{+}_{k}$',fontsize=fontSize)
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([5e-01,5e+02])
#ax2.set_aspect("equal")
ax2.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
ax3.semilogx(y_100,Dk_100,'r:',y_200,Dk_200,'g-.',y_300,Dk_300,'b--',y_400,Dk_400,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_ylabel('$D^{+}_{k}$',fontsize=fontSize)
ax3.text(3e-01,0.095,'c)',fontsize=fontSize)
ax3.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax4.semilogx(y_100,eps_100,'r:',y_200,eps_200,'g-.',y_300,eps_300,'b--',y_400,eps_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_ylabel(r'$\epsilon^{+}$',fontsize=fontSize)
ax4.text(3e-01,0.195,'d)',fontsize=fontSize)
ax4.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax4.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
plt.savefig("Fig_Budget_k_sqr.eps", format="eps", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
#plt.savefig("Fig_momentum_sqr_tau.png", format="png", dpi=1200, transparent=False, bbox_inches = 'tight',pad_inches = 0)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
Peps_100 = df_100.Peps.values
Teps_100 = df_100.Teps.values
Deps_100 = df_100.Deps.values
epsEps_100 = df_100.epsEps.values
Peps_200 = df_200.Peps.values
Teps_200 = df_200.Teps.values
Deps_200 = df_200.Deps.values
epsEps_200 = df_200.epsEps.values
Peps_300 = df_300.Peps.values
Teps_300 = df_300.Teps.values
Deps_300 = df_300.Deps.values
epsEps_300 = df_300.epsEps.values
Peps_400 = df_400.Peps.values
Teps_400 = df_400.Teps.values
Deps_400 = df_400.Deps.values
epsEps_400 = df_400.epsEps.values
#fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1)
fontSizeLeg=16

fig.set_figheight(24)
fig.set_figwidth(6)
plt.rcParams['font.size'] = 16

ax1.semilogx(y_100,Peps_100,'r:',y_200,Peps_200,'g-.',y_300,Peps_300,'b--',y_400,Peps_400,'k')
ax1.text(3e-01,0.022,'a)',fontsize=fontSize)
ax1.set_ylabel(r'$P^{+}_{\epsilon}$',fontsize=fontSize)
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([5e-01,5e+02])
ax1.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax2.semilogx(y_100,Teps_100,'r:',y_200,Teps_200,'g-.',y_300,Teps_300,'b--',y_400,Teps_400,'k')
ax2.text(3e-01,0.0011,'b)',fontsize=fontSize)
ax2.set_ylabel(r'$T^{+}_{\epsilon}$',fontsize=fontSize)
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([5e-01,5e+02])
#ax2.set_aspect("equal")
ax2.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
ax3.semilogx(y_100,Deps_100,'r:',y_200,Deps_200,'g-.',y_300,Deps_300,'b--',y_400,Deps_400,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_ylabel(r'$D^{+}_{\epsilon}$',fontsize=fontSize)
ax3.text(3e-01,0.0052,'c)',fontsize=fontSize)
ax3.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax4.semilogx(y_100,-epsEps_100,'r:',y_200,-epsEps_200,'g-.',y_300,-epsEps_300,'b--',y_400,-epsEps_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_ylabel(r'$\epsilon^{+}_{\epsilon}$',fontsize=fontSize)
ax4.text(3e-01,0.0155,'d)',fontsize=fontSize)
ax4.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax4.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
plt.savefig("Fig_Budget_eps_col.eps", format="eps", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
#plt.savefig("Fig_momentum_col_tau.png", format="png", dpi=1200, transparent=False, bbox_inches = 'tight',pad_inches = 0)
plt. show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_41881/1745291217.py in <module>
#      43 #plt.ylim([0, 20])
#      44 ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
# ---> 45 ax4.semilogx(y_100,-epsEps_100,'r:',y_200,-epsEps_200,'g-.',y_300,-epsEps_300,'b--',y_400,-epsEps_400,'k')
#      46 ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
#      47 ax4.set_ylabel(r'$\epsilon^{+}_{\epsilon}$',fontsize=fontSize)
#
# TypeError: bad operand type for unary -: 'str'
# Error in callback <function flush_figures at 0x7f133fad1290> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
# ...

# %%
Peps_100 = df_100.Peps.values
Teps_100 = df_100.Teps.values
Deps_100 = df_100.Deps.values
epsEps_100 = df_100.epsEps.values
Peps_200 = df_200.Peps.values
Teps_200 = df_200.Teps.values
Deps_200 = df_200.Deps.values
epsEps_200 = df_200.epsEps.values
Peps_300 = df_300.Peps.values
Teps_300 = df_300.Teps.values
Deps_300 = df_300.Deps.values
epsEps_300 = df_300.epsEps.values
Peps_400 = df_400.Peps.values
Teps_400 = df_400.Teps.values
Deps_400 = df_400.Deps.values
epsEps_400 = df_400.epsEps.values

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fontSizeLeg=16

fig.set_figheight(12)
fig.set_figwidth(12)
plt.rcParams['font.size'] = 16

ax1.semilogx(y_100,Peps_100,'r:',y_200,Peps_200,'g-.',y_300,Peps_300,'b--',y_400,Peps_400,'k')
ax1.text(3e-01,0.022,'a)',fontsize=fontSize)
ax1.set_ylabel(r'$P^{+}_{\epsilon}$',fontsize=fontSize)
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([5e-01,5e+02])
ax1.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax2.semilogx(y_100,Teps_100,'r:',y_200,Teps_200,'g-.',y_300,Teps_300,'b--',y_400,Teps_400,'k')
ax2.text(3e-01,0.0011,'b)',fontsize=fontSize)
ax2.set_ylabel(r'$T^{+}_{\epsilon}$',fontsize=fontSize)
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([5e-01,5e+02])
#ax2.set_aspect("equal")
ax2.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
ax3.semilogx(y_100,Deps_100,'r:',y_200,Deps_200,'g-.',y_300,Deps_300,'b--',y_400,Deps_400,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_ylabel(r'$D^{+}_{\epsilon}$',fontsize=fontSize)
ax3.text(3e-01,0.0052,'c)',fontsize=fontSize)
ax3.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
ax4.semilogx(y_100,-epsEps_100,'r:',y_200,-epsEps_200,'g-.',y_300,-epsEps_300,'b--',y_400,-epsEps_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_ylabel(r'$\epsilon^{+}_{\epsilon}$',fontsize=fontSize)
ax4.text(3e-01,0.0155,'d)',fontsize=fontSize)
ax4.set_xlim([5e-01,5e+02])
#plt.ylim([0, 20])
ax4.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=300$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg) 
plt.savefig("Fig_Budget_eps_sqr.eps", format="eps", dpi=1200, transparent=False, bbox_inches = 'tight',
    pad_inches = 0)
#plt.savefig("Fig_momentum_sqr_tau.png", format="png", dpi=1200, transparent=False, bbox_inches = 'tight',pad_inches = 0)
plt. show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_41881/2005214409.py in <module>
#      43 #plt.ylim([0, 20])
#      44 ax3.legend([r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$'],fontsize=fontSizeLeg)
# ---> 45 ax4.semilogx(y_100,-epsEps_100,'r:',y_200,-epsEps_200,'g-.',y_300,-epsEps_300,'b--',y_400,-epsEps_400,'k')
#      46 ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
#      47 ax4.set_ylabel(r'$\epsilon^{+}_{\epsilon}$',fontsize=fontSize)
#
# TypeError: bad operand type for unary -: 'str'
# Error in callback <function flush_figures at 0x7f133fad1290> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
# ...

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.set_figheight(12)
fig.set_figwidth(12)
ax1.semilogx(y_100,Pk_100,'r:',y_100,Tk_100,'g-.',y_100,Dk_100,'b--',y_100,-eps_100,'k')
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([1e-01,1e+02])
ax1.text(5e-02,0.21,'a)',fontsize=fontSize)
#plt.ylim([0, 20])
ax1.legend([r'$P_k$',r'$T_k$',r'$D_k$',r'$-\epsilon_k$'],fontsize=fontSizeLeg) 
ax2.semilogx(y_200,Pk_200,'r:',y_200,Tk_200,'g-.',y_200,Dk_200,'b--',y_200,-eps_200,'k')
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([2.5e-01,2e+02])
ax2.text(1.5e-01,0.22,'b)',fontsize=fontSize)
#plt.ylim([0, 20])
ax2.legend([r'$P_k$',r'$T_k$',r'$D_k$',r'$-\epsilon_k$'],fontsize=fontSizeLeg)
ax3.semilogx(y_300,Pk_300,'r:',y_300,Tk_300,'g-.',y_300,Dk_300,'b--',y_300,-eps_300,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_xlim([3e-01,3e+02])
ax3.text(2e-01,0.225,'c)',fontsize=fontSize)
#plt.ylim([0, 20])
ax3.legend([r'$P_k$',r'$T_k$',r'$D_k$',r'$-\epsilon_k$'],fontsize=fontSizeLeg)
ax4.semilogx(y_400,Pk_400,'r:',y_400,Tk_400,'g-.',y_400,Dk_400,'b--',y_400,-eps_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_xlim([4e-01,4e+02])
ax4.text(3e-01,0.24,'d)',fontsize=fontSize)
#plt.ylim([0, 20])
ax4.legend([r'$P_k$',r'$T_k$',r'$D_k$',r'$-\epsilon_k$'],fontsize=fontSizeLeg)
plt.savefig("Budget_k_sq.eps", format="eps", dpi=1200, transparent=False)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.set_figheight(16)
fig.set_figwidth(16)
ax1.semilogx(y_100,Peps_100,'r:',y_100,Teps_100,'g-.',y_100,Deps_100,'b--',y_100,epsEps_100,'k')
ax1.set_xlabel('$y^{+}$',fontsize=fontSize)
ax1.set_xlim([1e-01,1e+02])
#plt.ylim([0, 20])
ax1.legend([r'$P_{\epsilon}$',r'$T_{\epsilon}$',r'$D_{\epsilon}$',r'$\epsilon_{\epsilon}$'],fontsize=fontSizeLeg) 
ax2.semilogx(y_200,Peps_200,'r:',y_200,Teps_200,'g-.',y_200,Deps_200,'b--',y_200,epsEps_200,'k')
ax2.set_xlabel('$y^{+}$',fontsize=fontSize)
ax2.set_xlim([2e-01,2e+02])
#plt.ylim([0, 20])
ax2.legend([r'$P_{\epsilon}$',r'$T_{\epsilon}$',r'$D_{\epsilon}$',r'$\epsilon_{\epsilon}$'],fontsize=fontSizeLeg)
ax3.semilogx(y_300,Peps_300,'r:',y_300,Teps_300,'g-.',y_300,Deps_300,'b--',y_300,epsEps_300,'k')
ax3.set_xlabel('$y^{+}$',fontsize=fontSize)
ax3.set_xlim([3e-01,3e+02])
#plt.ylim([0, 20])
ax3.legend([r'$P_{\epsilon}$',r'$T_{\epsilon}$',r'$D_{\epsilon}$',r'$\epsilon_{\epsilon}$'],fontsize=fontSizeLeg)
ax4.semilogx(y_400,Peps_400,'r:',y_400,Teps_400,'g-.',y_400,Deps_400,'b--',y_400,epsEps_400,'k')
ax4.set_xlabel('$y^{+}$',fontsize=fontSize)
ax4.set_xlim([4e-01,4e+02])
#plt.ylim([0, 20])
ax4.legend([r'$P_{\epsilon}$',r'$T_{\epsilon}$',r'$D_{\epsilon}$',r'$\epsilon_{\epsilon}$'],fontsize=fontSizeLeg)
plt.savefig("Budget_epsilon_sq.eps", format="eps", dpi=1200, transparent=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_41881/2683077082.py in <module>
#      22 #plt.ylim([0, 20])
#      23 ax4.legend([r'$P_{\epsilon}$',r'$T_{\epsilon}$',r'$D_{\epsilon}$',r'$\epsilon_{\epsilon}$'],fontsize=fontSizeLeg)
# ---> 24 plt.savefig("Budget_epsilon_sq.eps", format="eps", dpi=1200, transparent=False)
#      25 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     977 def savefig(*args, **kwargs):
#     978     fig = gcf()
# --> 979     res = fig.savefig(*args, **kwargs)
#     980     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     981     return res
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3044                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
# ...

# %%
y_200 = df_200[' "y"'].values
U_200 = df_200.U.values
y_300 = df_300[' "y"'].values
U_300 = df_300.U.values
y_100 = df_100[' "y"'].values
U_100 = df_100.U.values
y_400 = df_400[' "y"'].values
U_400 = df_400.U.values
yl = y_400[0:160]
Ul = yl
yt = y_400[160:-1]
Ut = (1/0.4)*np.log(yt)+6.2
plt.figure(1)
plt.semilogx(yl,Ul,'c-.',yt,Ut,'m--',y_100,U_100,'r:',y_200,U_200,'g-.',y_300,U_300,'b--',y_400,U_400,'k')
plt.xlabel('$y^{+}$')
plt.ylabel('$U^{+}$')
plt.xlim([5e+01,5e+02])
plt.ylim([15,22])
plt.legend(['$U^{+}=y^{+}$','$U^{+}=\kappa^{-1}\ln{y^{+}}+C$',r'$Re_{\tau}=100$',r'$Re_{\tau}=200$',r'$Re_{\tau}=300$',r'$Re_{\tau}=400$']) 
plt.show()
